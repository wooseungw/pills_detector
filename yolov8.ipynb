# %%
import ultralytics
from ultralytics import YOLO
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.159  Python-3.11.4 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce RTX 4070 Ti, 12282MiB)
# Setup complete  (20 CPUs, 31.8 GB RAM, 657.4/930.2 GB disk)

# %%
# Load YOLOv8n, train it on COCO128 for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolov8n.pt')  # load a pretrained YOLOv8n detection model
model.train(data='C:\Workspace\pills_detector\dataeset\data.yaml',verbose=True, epochs=150)  # train the model

# %%
# Load YOLOv8n, train it on COCO128 for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolov8n.pt')  # load a pretrained YOLOv8n detection model
model.train(data='C:\Workspace\pills_detector\dataeset\data.yaml',verbose=True, epochs=50, lrf=0.01,patience=10, batch=32)  # train the model
# Out:
# Ultralytics YOLOv8.0.159  Python-3.11.4 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce RTX 4070 Ti, 12282MiB)
# ...

# %%
# Load YOLOv8n, train it on COCO128 for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('./runs/detect/train6/weights/best.pt')  # load a pretrained YOLOv8n detection model
model.train(data='C:\Workspace\pills_detector\dataeset\data.yaml',verbose=True, epochs=50, lrf=0.01,patience=10, batch=32)  # train the model

# %%
# Load YOLOv8n, train it on COCO128 for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('./runs/detect/train15/weights/best.pt')  # load a pretrained YOLOv8n detection model
model.train(data='C:\Workspace\pills_detector\medi_23\medicine.v108i.yolov8\data.yaml',verbose=True, epochs=10, lrf=0.01,patience=10, batch=32)  # train the model
# Out:
# New https://pypi.org/project/ultralytics/8.0.161 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.159  Python-3.11.4 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce RTX 4070 Ti, 12282MiB)
# ...

# %%
class_names = results.names
print("All class names:", class_names)

# %%
model.val(save_json=True)

# %%
test1 = results.maps>=0.9

# %%
nameeee = results.names

# %%
nameeee = pd.Series(nameeee)
nameeee.to_csv('nameeee', encoding = 'cp949')

# %%
test1 =pd.Series(test1)
test1.to_csv('test1', encoding='cp949')

# %%
model = YOLO('C:\Workspace/pills_detector/runs/detect/train13/weights/best.pt')
results = model('C:\Workspace\pills_detector\medicine_origin\Amocla Tab..jpg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 model = YOLO('C:\Workspace/pills_detector/runs/detect/train13/weights/best.pt')
#       2 results = model('C:\Workspace\pills_detector\medicine_origin\Amocla Tab..jpg')
#
# NameError: name 'YOLO' is not defined

# %%
from PIL import Image
from ultralytics import YOLO

# Load a pretrained YOLOv8n model
model = YOLO('C:\Workspace/pills_detector/runs/detect/train6/weights/best.pt')

# Run inference on 'bus.jpg'
results = model('medicine_origin\Cypro Tab..jpg')

# Show the results
for r in results:
    im_array = r.plot()  # plot a BGR numpy array of predictions
    im = Image.fromarray(im_array[..., ::-1])  # RGB PIL image
    im.show()  # show image
    im.save('results.jpg')  # save image
# Out:
# image 1/1 c:\Workspace\pills_detector\medicine_origin\Cypro Tab..jpg: 352x640 2 Cypros, 1 Dovato, 36.9ms
# Speed: 4.0ms preprocess, 36.9ms inference, 4.0ms postprocess per image at shape (1, 3, 352, 640)
