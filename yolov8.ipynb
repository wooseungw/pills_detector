# %%
import ultralytics
from ultralytics import YOLO
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.157  Python-3.11.4 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce RTX 4070 Ti, 12282MiB)
# Setup complete  (20 CPUs, 31.8 GB RAM, 660.7/930.2 GB disk)

# %%
# Load YOLOv8n, train it on COCO128 for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolov8n.pt')  # load a pretrained YOLOv8n detection model
model.train(data='C:\Workspace\pills_detector\dataeset\data.yaml',verbose=True, epochs=150)  # train the model
# Out:
# Ultralytics YOLOv8.0.157  Python-3.11.4 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce RTX 4070 Ti, 12282MiB)
# ...

# %%
model.val()
# Out:
# Ultralytics YOLOv8.0.157  Python-3.11.4 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce RTX 4070 Ti, 12282MiB)
# val: Scanning C:\Workspace\pills_detector\dataeset\valid\labels.cache... 507 images, 0 backgrounds, 0 corrupt: 100%|██████████| 507/507 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 32/32 [00:04<00:00,  7.90it/s]
#                    all        507       1014      0.895      0.733      0.833      0.796
#  A Progen Cefixime Cap        507          2      0.734          1      0.995      0.995
# A Progen Clarithromycin Tab        507          2      0.884          1      0.995      0.995
# A Progen Clarithromycin Tab-500mg        507          2      0.951          1      0.995      0.923
#           Aclova 400mg        507          2      0.821          1      0.995      0.995
#                 Aclova        507          2      0.853          1      0.995      0.895
# ...

# %%
model = YOLO('C:\Workspace/pills_detector/runs/detect/train2/weights/best.pt')
results = model('C:\Workspace\pills_detector\medicine_origin\Amocla Tab..jpg')
# Out:
# image 1/1 C:\Workspace\pills_detector\medicine_origin\Amocla Tab..jpg: 352x640 (no detections), 109.1ms
# Speed: 3.0ms preprocess, 109.1ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)

# %%
from PIL import Image
from ultralytics import YOLO

# Load a pretrained YOLOv8n model
model = YOLO('C:\Workspace/pills_detector/runs/detect/train2/weights/best.pt')

# Run inference on 'bus.jpg'
results = model('medicine_origin\Amoclan Duo Tab.500mg.jpg')

# Show the results
for r in results:
    im_array = r.plot()  # plot a BGR numpy array of predictions
    im = Image.fromarray(im_array[..., ::-1])  # RGB PIL image
    im.show()  # show image
    im.save('results.jpg')  # save image
# Out:
# image 1/1 c:\Workspace\pills_detector\medicine_origin\Amoclan Duo Tab.500mg.jpg: 352x640 2 Amoclan Duo Tab- Myungmoons, 70.3ms
# Speed: 2.0ms preprocess, 70.3ms inference, 10.0ms postprocess per image at shape (1, 3, 352, 640)
